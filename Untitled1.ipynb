# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('credit_risk_dataset.csv')
df = data.copy()

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.173202           0.163106
# person_income                 0.173202       1.000000           0.134268
# person_emp_length             0.163106       0.134268           1.000000
# loan_amnt                     0.050787       0.266820           0.113082
# loan_int_rate                 0.012580       0.000792          -0.056405
# loan_status                  -0.021629      -0.144449          -0.082489
# loan_percent_income          -0.042411      -0.254471          -0.054111
# cb_person_cred_hist_length    0.859133       0.117987           0.144699
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.050787       0.012580    -0.021629
# person_income                0.266820       0.000792    -0.144449
# person_emp_length            0.113082      -0.056405    -0.082489
# loan_amnt                    1.000000       0.146813     0.105376
# loan_int_rate                0.146813       1.000000     0.335133
# loan_status                  0.105376       0.335133     1.000000
# loan_percent_income          0.572612       0.120314     0.379366
# cb_person_cred_hist_length   0.041967       0.016696    -0.015529
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.042411                    0.859133
# person_income                         -0.254471                    0.117987
# person_emp_length                     -0.054111                    0.144699
# loan_amnt                              0.572612                    0.041967
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379366                   -0.015529
# loan_percent_income                    1.000000                   -0.031690
# cb_person_cred_hist_length            -0.031690                    1.000000

# %%
df.isna().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
df.person_emp_length.fillna(df.person_emp_length.mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length                0
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df.dropna(inplace=True)
#df.loan_int_rate.fillna(df.loan_int_rate.mean(), inplace=True) worst correlation!!

# %%
df.isna().any()
# Out:
# person_age                    False
# person_income                 False
# person_home_ownership         False
# person_emp_length             False
# loan_intent                   False
# loan_grade                    False
# loan_amnt                     False
# loan_int_rate                 False
# loan_status                   False
# loan_percent_income           False
# cb_person_default_on_file     False
# cb_person_cred_hist_length    False
# dtype: bool

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.177265           0.163709
# person_income                 0.177265       1.000000           0.135880
# person_emp_length             0.163709       0.135880           1.000000
# loan_amnt                     0.053954       0.269182           0.109423
# loan_int_rate                 0.012580       0.000792          -0.055419
# loan_status                  -0.021803      -0.143951          -0.081095
# loan_percent_income          -0.042231      -0.253013          -0.054138
# cb_person_cred_hist_length    0.859808       0.116186           0.144499
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.053954       0.012580    -0.021803
# person_income                0.269182       0.000792    -0.143951
# person_emp_length            0.109423      -0.055419    -0.081095
# loan_amnt                    1.000000       0.146813     0.106557
# loan_int_rate                0.146813       1.000000     0.335133
# loan_status                  0.106557       0.335133     1.000000
# loan_percent_income          0.572679       0.120314     0.379160
# cb_person_cred_hist_length   0.045263       0.016696    -0.014204
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.042231                    0.859808
# person_income                         -0.253013                    0.116186
# person_emp_length                     -0.054138                    0.144499
# loan_amnt                              0.572679                    0.045263
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379160                   -0.014204
# loan_percent_income                    1.000000                   -0.030587
# cb_person_cred_hist_length            -0.030587                    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29465 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  29465 non-null  int64
#  1   person_income               29465 non-null  int64
#  2   person_home_ownership       29465 non-null  object
#  3   person_emp_length           29465 non-null  float64
#  4   loan_intent                 29465 non-null  object
#  5   loan_grade                  29465 non-null  object
#  6   loan_amnt                   29465 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 29465 non-null  int64
#  9   loan_percent_income         29465 non-null  float64
#  10  cb_person_default_on_file   29465 non-null  object
#  11  cb_person_cred_hist_length  29465 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 2.9+ MB

# %%
#detecting outliers

# %%
sns.boxplot(df.person_age)
# Out:
# <Axes: >

# %%
df.loc[df.person_age > 30 ,"person_age"].count()
# Out:
# 7002

# %%
df.loc[df['person_age']>(30+1.5*7),"person_age"] = (30+1.5*7)
# Out:
# C:\Users\Ömer\AppData\Local\Temp\ipykernel_9548\3213583188.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '40.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['person_age']>(30+1.5*7),"person_age"] = (30+1.5*7)

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.127706           0.177819
# person_income                 0.127706       1.000000           0.135880
# person_emp_length             0.177819       0.135880           1.000000
# loan_amnt                     0.059840       0.269182           0.109423
# loan_int_rate                 0.013872       0.000792          -0.055419
# loan_status                  -0.026013      -0.143951          -0.081095
# loan_percent_income          -0.044648      -0.253013          -0.054138
# cb_person_cred_hist_length    0.858485       0.116186           0.144499
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.059840       0.013872    -0.026013
# person_income                0.269182       0.000792    -0.143951
# person_emp_length            0.109423      -0.055419    -0.081095
# loan_amnt                    1.000000       0.146813     0.106557
# loan_int_rate                0.146813       1.000000     0.335133
# loan_status                  0.106557       0.335133     1.000000
# loan_percent_income          0.572679       0.120314     0.379160
# cb_person_cred_hist_length   0.045263       0.016696    -0.014204
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.044648                    0.858485
# person_income                         -0.253013                    0.116186
# person_emp_length                     -0.054138                    0.144499
# loan_amnt                              0.572679                    0.045263
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379160                   -0.014204
# loan_percent_income                    1.000000                   -0.030587
# cb_person_cred_hist_length            -0.030587                    1.000000

# %%
sns.boxplot(df['person_age'])
plt.show()

# %%
sns.boxplot(df.person_income)
plt.show()

# %%
df.loc[df['person_income']>(df.person_income.quantile(0.75)+1.5*(df.person_income.quantile(0.75) - df.person_income.quantile(0.25))),"person_income"] = (df.person_income.quantile(0.75)+1.5*(df.person_income.quantile(0.75) - df.person_income.quantile(0.25)))

# %%
sns.boxplot(df.person_income)
plt.show()

# %%
df.corr(numeric_only=True) # person_income correlation loan status 0.14 ->>> 0.24
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.129766           0.177819
# person_income                 0.129766       1.000000           0.196010
# person_emp_length             0.177819       0.196010           1.000000
# loan_amnt                     0.059840       0.420807           0.109423
# loan_int_rate                 0.013872      -0.017989          -0.055419
# loan_status                  -0.026013      -0.244648          -0.081095
# loan_percent_income          -0.044648      -0.366120          -0.054138
# cb_person_cred_hist_length    0.858485       0.096000           0.144499
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.059840       0.013872    -0.026013
# person_income                0.420807      -0.017989    -0.244648
# person_emp_length            0.109423      -0.055419    -0.081095
# loan_amnt                    1.000000       0.146813     0.106557
# loan_int_rate                0.146813       1.000000     0.335133
# loan_status                  0.106557       0.335133     1.000000
# loan_percent_income          0.572679       0.120314     0.379160
# cb_person_cred_hist_length   0.045263       0.016696    -0.014204
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.044648                    0.858485
# person_income                         -0.366120                    0.096000
# person_emp_length                     -0.054138                    0.144499
# loan_amnt                              0.572679                    0.045263
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379160                   -0.014204
# loan_percent_income                    1.000000                   -0.030587
# cb_person_cred_hist_length            -0.030587                    1.000000

# %%
sns.boxplot(df['person_emp_length'])
plt.show()

# %%
df.loc[df['person_emp_length']>(7+1.5*5),"person_emp_length"] = (7+1.5*5)

# %%
sns.boxplot(df['person_emp_length'])
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.129766           0.158296
# person_income                 0.129766       1.000000           0.203343
# person_emp_length             0.158296       0.203343           1.000000
# loan_amnt                     0.059840       0.420807           0.109741
# loan_int_rate                 0.013872      -0.017989          -0.060438
# loan_status                  -0.026013      -0.244648          -0.089187
# loan_percent_income          -0.044648      -0.366120          -0.059447
# cb_person_cred_hist_length    0.858485       0.096000           0.123247
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.059840       0.013872    -0.026013
# person_income                0.420807      -0.017989    -0.244648
# person_emp_length            0.109741      -0.060438    -0.089187
# loan_amnt                    1.000000       0.146813     0.106557
# loan_int_rate                0.146813       1.000000     0.335133
# loan_status                  0.106557       0.335133     1.000000
# loan_percent_income          0.572679       0.120314     0.379160
# cb_person_cred_hist_length   0.045263       0.016696    -0.014204
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.044648                    0.858485
# person_income                         -0.366120                    0.096000
# person_emp_length                     -0.059447                    0.123247
# loan_amnt                              0.572679                    0.045263
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379160                   -0.014204
# loan_percent_income                    1.000000                   -0.030587
# cb_person_cred_hist_length            -0.030587                    1.000000

# %%
#label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['loan_grade'] = le.fit_transform(df['loan_grade'])

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0        22.0          59000                  RENT               14.5
# 1        21.0           9600                   OWN                5.0
# 2        25.0           9600              MORTGAGE                1.0
# 3        23.0          65500                  RENT                4.0
# 4        24.0          54400                  RENT                8.0
#
#   loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL           3      35000          16.02            1
# 1   EDUCATION           1       1000          11.14            0
# 2     MEDICAL           2       5500          12.87            1
# 3     MEDICAL           2      35000          15.23            1
# 4     MEDICAL           2      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.corr(numeric_only= True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.129766           0.158296
# person_income                 0.129766       1.000000           0.203343
# person_emp_length             0.158296       0.203343           1.000000
# loan_grade                    0.016469      -0.013760          -0.053715
# loan_amnt                     0.059840       0.420807           0.109741
# loan_int_rate                 0.013872      -0.017989          -0.060438
# loan_status                  -0.026013      -0.244648          -0.089187
# loan_percent_income          -0.044648      -0.366120          -0.059447
# cb_person_cred_hist_length    0.858485       0.096000           0.123247
#
#                             loan_grade  loan_amnt  loan_int_rate  loan_status  \
# person_age                    0.016469   0.059840       0.013872    -0.026013
# person_income                -0.013760   0.420807      -0.017989    -0.244648
# person_emp_length            -0.053715   0.109741      -0.060438    -0.089187
# loan_grade                    1.000000   0.150761       0.933684     0.375788
# loan_amnt                     0.150761   1.000000       0.146813     0.106557
# loan_int_rate                 0.933684   0.146813       1.000000     0.335133
# loan_status                   0.375788   0.106557       0.335133     1.000000
# loan_percent_income           0.123198   0.572679       0.120314     0.379160
# cb_person_cred_hist_length    0.015894   0.045263       0.016696    -0.014204
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.044648                    0.858485
# person_income                         -0.366120                    0.096000
# person_emp_length                     -0.059447                    0.123247
# loan_grade                             0.123198                    0.015894
# loan_amnt                              0.572679                    0.045263
# loan_int_rate                          0.120314                    0.016696
# loan_status                            0.379160                   -0.014204
# loan_percent_income                    1.000000                   -0.030587
# cb_person_cred_hist_length            -0.030587                    1.000000

# %%
df.person_home_ownership.value_counts()
# Out:
# person_home_ownership
# RENT        14893
# MORTGAGE    12122
# OWN          2356
# OTHER          94
# Name: count, dtype: int64

# %%
mapping = {'OWN': 3, 'MORTGAGE':1, 'RENT':0, 'OTHER':2}

# %%
df['person_home_ownership'] = df['person_home_ownership'].map(mapping)

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 0        22.0          59000                      0               14.5
# 1        21.0           9600                      3                5.0
# 2        25.0           9600                      1                1.0
# 3        23.0          65500                      0                4.0
# 4        24.0          54400                      0                8.0
#
#   loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL           3      35000          16.02            1
# 1   EDUCATION           1       1000          11.14            0
# 2     MEDICAL           2       5500          12.87            1
# 3     MEDICAL           2      35000          15.23            1
# 4     MEDICAL           2      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.corr(numeric_only= True)
# Out:
#                             person_age  person_income  person_home_ownership  \
# person_age                    1.000000       0.129766               0.024763
# person_income                 0.129766       1.000000               0.123431
# person_home_ownership         0.024763       0.123431               1.000000
# person_emp_length             0.158296       0.203343               0.158899
# loan_grade                    0.016469      -0.013760              -0.081691
# loan_amnt                     0.059840       0.420807               0.051572
# loan_int_rate                 0.013872      -0.017989              -0.089671
# loan_status                  -0.026013      -0.244648              -0.209181
# loan_percent_income          -0.044648      -0.366120              -0.038733
# cb_person_cred_hist_length    0.858485       0.096000               0.019444
#
#                             person_emp_length  loan_grade  loan_amnt  \
# person_age                           0.158296    0.016469   0.059840
# person_income                        0.203343   -0.013760   0.420807
# person_home_ownership                0.158899   -0.081691   0.051572
# person_emp_length                    1.000000   -0.053715   0.109741
# loan_grade                          -0.053715    1.000000   0.150761
# loan_amnt                            0.109741    0.150761   1.000000
# loan_int_rate                       -0.060438    0.933684   0.146813
# loan_status                         -0.089187    0.375788   0.106557
# loan_percent_income                 -0.059447    0.123198   0.572679
# cb_person_cred_hist_length           0.123247    0.015894   0.045263
#
#                             loan_int_rate  loan_status  loan_percent_income  \
# person_age                       0.013872    -0.026013            -0.044648
# person_income                   -0.017989    -0.244648            -0.366120
# person_home_ownership           -0.089671    -0.209181            -0.038733
# person_emp_length               -0.060438    -0.089187            -0.059447
# loan_grade                       0.933684     0.375788             0.123198
# loan_amnt                        0.146813     0.106557             0.572679
# loan_int_rate                    1.000000     0.335133             0.120314
# loan_status                      0.335133     1.000000             0.379160
# loan_percent_income              0.120314     0.379160             1.000000
# cb_person_cred_hist_length       0.016696    -0.014204            -0.030587
#
#                             cb_person_cred_hist_length
# person_age                                    0.858485
# person_income                                 0.096000
# person_home_ownership                         0.019444
# person_emp_length                             0.123247
# loan_grade                                    0.015894
# loan_amnt                                     0.045263
# loan_int_rate                                 0.016696
# loan_status                                  -0.014204
# loan_percent_income                          -0.030587
# cb_person_cred_hist_length                    1.000000

# %%
df.loan_intent.value_counts()
# Out:
# loan_intent
# EDUCATION            5854
# MEDICAL              5451
# VENTURE              5153
# PERSONAL             5014
# DEBTCONSOLIDATION    4703
# HOMEIMPROVEMENT      3290
# Name: count, dtype: int64

# %%
df.cb_person_default_on_file.value_counts()
# Out:
# cb_person_default_on_file
# N    24252
# Y     5213
# Name: count, dtype: int64

# %%
df.cb_person_default_on_file = le.fit_transform(df.cb_person_default_on_file)

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 0        22.0          59000                      0               14.5
# 1        21.0           9600                      3                5.0
# 2        25.0           9600                      1                1.0
# 3        23.0          65500                      0                4.0
# 4        24.0          54400                      0                8.0
#
#   loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL           3      35000          16.02            1
# 1   EDUCATION           1       1000          11.14            0
# 2     MEDICAL           2       5500          12.87            1
# 3     MEDICAL           2      35000          15.23            1
# 4     MEDICAL           2      35000          14.27            1
#
#    loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                          1                           3
# 1                 0.10                          0                           2
# 2                 0.57                          0                           3
# 3                 0.53                          0                           2
# 4                 0.55                          1                           4

# %%
df = df.join(pd.get_dummies(df.loan_intent, prefix ='loan_intent',dtype=int)).drop('loan_intent', axis=1)

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 0        22.0          59000                      0               14.5
# 1        21.0           9600                      3                5.0
# 2        25.0           9600                      1                1.0
# 3        23.0          65500                      0                4.0
# 4        24.0          54400                      0                8.0
#
#    loan_grade  loan_amnt  loan_int_rate  loan_status  loan_percent_income  \
# 0           3      35000          16.02            1                 0.59
# 1           1       1000          11.14            0                 0.10
# 2           2       5500          12.87            1                 0.57
# 3           2      35000          15.23            1                 0.53
# 4           2      35000          14.27            1                 0.55
#
#    cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                          1                           3
# 1                          0                           2
# 2                          0                           3
# 3                          0                           2
# 4                          1                           4
#
#    loan_intent_DEBTCONSOLIDATION  loan_intent_EDUCATION  \
# 0                              0                      0
# 1                              0                      1
# 2                              0                      0
# 3                              0                      0
# 4                              0                      0
#
#    loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 0                            0                    0                     1
# 1                            0                    0                     0
# 2                            0                    1                     0
# 3                            0                    1                     0
# 4                            0                    1                     0
#
#    loan_intent_VENTURE
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29465 entries, 0 to 32580
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   person_age                     29465 non-null  float64
#  1   person_income                  29465 non-null  int64
#  2   person_home_ownership          29465 non-null  int64
#  3   person_emp_length              29465 non-null  float64
#  4   loan_grade                     29465 non-null  int32
#  5   loan_amnt                      29465 non-null  int64
#  6   loan_int_rate                  29465 non-null  float64
#  7   loan_status                    29465 non-null  int64
#  8   loan_percent_income            29465 non-null  float64
#  9   cb_person_default_on_file      29465 non-null  int32
#  10  cb_person_cred_hist_length     29465 non-null  int64
#  11  loan_intent_DEBTCONSOLIDATION  29465 non-null  int32
#  12  loan_intent_EDUCATION          29465 non-null  int32
#  13  loan_intent_HOMEIMPROVEMENT    29465 non-null  int32
#  14  loan_intent_MEDICAL            29465 non-null  int32
#  15  loan_intent_PERSONAL           29465 non-null  int32
#  16  loan_intent_VENTURE            29465 non-null  int32
# dtypes: float64(4), int32(8), int64(5)
# memory usage: 4.2 MB

# %%
df.corr()
# Out:
#                                person_age  person_income  \
# person_age                       1.000000       0.129766
# person_income                    0.129766       1.000000
# person_home_ownership            0.024763       0.123431
# person_emp_length                0.158296       0.203343
# loan_grade                       0.016469      -0.013760
# loan_amnt                        0.059840       0.420807
# loan_int_rate                    0.013872      -0.017989
# loan_status                     -0.026013      -0.244648
# loan_percent_income             -0.044648      -0.366120
# cb_person_default_on_file        0.011324      -0.013767
# cb_person_cred_hist_length       0.858485       0.096000
# loan_intent_DEBTCONSOLIDATION   -0.003423       0.000915
# loan_intent_EDUCATION           -0.100294      -0.014384
# loan_intent_HOMEIMPROVEMENT      0.093048       0.080313
# loan_intent_MEDICAL              0.019322      -0.065451
# loan_intent_PERSONAL             0.018680       0.008197
# loan_intent_VENTURE             -0.006729       0.006434
#
#                                person_home_ownership  person_emp_length  \
# person_age                                  0.024763           0.158296
# person_income                               0.123431           0.203343
# person_home_ownership                       1.000000           0.158899
# person_emp_length                           0.158899           1.000000
# loan_grade                                 -0.081691          -0.053715
# loan_amnt                                   0.051572           0.109741
# loan_int_rate                              -0.089671          -0.060438
# loan_status                                -0.209181          -0.089187
# loan_percent_income                        -0.038733          -0.059447
# cb_person_default_on_file                  -0.038005          -0.031442
# cb_person_cred_hist_length                  0.019444           0.123247
# loan_intent_DEBTCONSOLIDATION              -0.086250           0.001125
# loan_intent_EDUCATION                       0.000812          -0.035815
# loan_intent_HOMEIMPROVEMENT                 0.043480           0.029625
# loan_intent_MEDICAL                        -0.044969          -0.005498
# loan_intent_PERSONAL                        0.009797           0.011479
# loan_intent_VENTURE                         0.082531           0.006238
#
#                                loan_grade  loan_amnt  loan_int_rate  \
# person_age                       0.016469   0.059840       0.013872
# person_income                   -0.013760   0.420807      -0.017989
# person_home_ownership           -0.081691   0.051572      -0.089671
# person_emp_length               -0.053715   0.109741      -0.060438
# loan_grade                       1.000000   0.150761       0.933684
# loan_amnt                        0.150761   1.000000       0.146813
# loan_int_rate                    0.933684   0.146813       1.000000
# loan_status                      0.375788   0.106557       0.335133
# loan_percent_income              0.123198   0.572679       0.120314
# cb_person_default_on_file        0.536324   0.040121       0.501072
# cb_person_cred_hist_length       0.015894   0.045263       0.016696
# loan_intent_DEBTCONSOLIDATION   -0.003381   0.000165      -0.003823
# loan_intent_EDUCATION           -0.010378  -0.007927      -0.009440
# loan_intent_HOMEIMPROVEMENT      0.029122   0.041174       0.020728
# loan_intent_MEDICAL              0.004407  -0.024988       0.007131
# loan_intent_PERSONAL            -0.004250   0.000495      -0.001883
# loan_intent_VENTURE             -0.010284  -0.000916      -0.009010
#
#                                loan_status  loan_percent_income  \
# person_age                       -0.026013            -0.044648
# person_income                    -0.244648            -0.366120
# person_home_ownership            -0.209181            -0.038733
# person_emp_length                -0.089187            -0.059447
# loan_grade                        0.375788             0.123198
# loan_amnt                         0.106557             0.572679
# loan_int_rate                     0.335133             0.120314
# loan_status                       1.000000             0.379160
# loan_percent_income               0.379160             1.000000
# cb_person_default_on_file         0.180179             0.035605
# cb_person_cred_hist_length       -0.014204            -0.030587
# loan_intent_DEBTCONSOLIDATION     0.070371             0.003445
# loan_intent_EDUCATION            -0.056163             0.000443
# loan_intent_HOMEIMPROVEMENT       0.036780            -0.018171
# loan_intent_MEDICAL               0.058117             0.013649
# loan_intent_PERSONAL             -0.019635            -0.003956
# loan_intent_VENTURE              -0.079333             0.001240
#
#                                cb_person_default_on_file  \
# person_age                                      0.011324
# person_income                                  -0.013767
# person_home_ownership                          -0.038005
# person_emp_length                              -0.031442
# loan_grade                                      0.536324
# loan_amnt                                       0.040121
# loan_int_rate                                   0.501072
# loan_status                                     0.180179
# loan_percent_income                             0.035605
# cb_person_default_on_file                       1.000000
# cb_person_cred_hist_length                      0.008753
# loan_intent_DEBTCONSOLIDATION                  -0.001229
# loan_intent_EDUCATION                          -0.006843
# loan_intent_HOMEIMPROVEMENT                     0.015511
# loan_intent_MEDICAL                             0.001283
# loan_intent_PERSONAL                           -0.002387
# loan_intent_VENTURE                            -0.003436
#
#                                cb_person_cred_hist_length  \
# person_age                                       0.858485
# person_income                                    0.096000
# person_home_ownership                            0.019444
# person_emp_length                                0.123247
# loan_grade                                       0.015894
# loan_amnt                                        0.045263
# loan_int_rate                                    0.016696
# loan_status                                     -0.014204
# loan_percent_income                             -0.030587
# cb_person_default_on_file                        0.008753
# cb_person_cred_hist_length                       1.000000
# loan_intent_DEBTCONSOLIDATION                   -0.008232
# loan_intent_EDUCATION                           -0.079732
# loan_intent_HOMEIMPROVEMENT                      0.060019
# loan_intent_MEDICAL                              0.014615
# loan_intent_PERSONAL                             0.034690
# loan_intent_VENTURE                             -0.007332
#
#                                loan_intent_DEBTCONSOLIDATION  \
# person_age                                         -0.003423
# person_income                                       0.000915
# person_home_ownership                              -0.086250
# person_emp_length                                   0.001125
# loan_grade                                         -0.003381
# loan_amnt                                           0.000165
# loan_int_rate                                      -0.003823
# loan_status                                         0.070371
# loan_percent_income                                 0.003445
# cb_person_default_on_file                          -0.001229
# cb_person_cred_hist_length                         -0.008232
# loan_intent_DEBTCONSOLIDATION                       1.000000
# loan_intent_EDUCATION                              -0.217002
# loan_intent_HOMEIMPROVEMENT                        -0.154507
# loan_intent_MEDICAL                                -0.207635
# loan_intent_PERSONAL                               -0.197351
# loan_intent_VENTURE                                -0.200639
#
#                                loan_intent_EDUCATION  \
# person_age                                 -0.100294
# person_income                              -0.014384
# person_home_ownership                       0.000812
# person_emp_length                          -0.035815
# loan_grade                                 -0.010378
# loan_amnt                                  -0.007927
# loan_int_rate                              -0.009440
# loan_status                                -0.056163
# loan_percent_income                         0.000443
# cb_person_default_on_file                  -0.006843
# cb_person_cred_hist_length                 -0.079732
# loan_intent_DEBTCONSOLIDATION              -0.217002
# loan_intent_EDUCATION                       1.000000
# loan_intent_HOMEIMPROVEMENT                -0.176532
# loan_intent_MEDICAL                        -0.237233
# loan_intent_PERSONAL                       -0.225483
# loan_intent_VENTURE                        -0.229239
#
#                                loan_intent_HOMEIMPROVEMENT  \
# person_age                                        0.093048
# person_income                                     0.080313
# person_home_ownership                             0.043480
# person_emp_length                                 0.029625
# loan_grade                                        0.029122
# loan_amnt                                         0.041174
# loan_int_rate                                     0.020728
# loan_status                                       0.036780
# loan_percent_income                              -0.018171
# cb_person_default_on_file                         0.015511
# cb_person_cred_hist_length                        0.060019
# loan_intent_DEBTCONSOLIDATION                    -0.154507
# loan_intent_EDUCATION                            -0.176532
# loan_intent_HOMEIMPROVEMENT                       1.000000
# loan_intent_MEDICAL                              -0.168912
# loan_intent_PERSONAL                             -0.160546
# loan_intent_VENTURE                              -0.163220
#
#                                loan_intent_MEDICAL  loan_intent_PERSONAL  \
# person_age                                0.019322              0.018680
# person_income                            -0.065451              0.008197
# person_home_ownership                    -0.044969              0.009797
# person_emp_length                        -0.005498              0.011479
# loan_grade                                0.004407             -0.004250
# loan_amnt                                -0.024988              0.000495
# loan_int_rate                             0.007131             -0.001883
# loan_status                               0.058117             -0.019635
# loan_percent_income                       0.013649             -0.003956
# cb_person_default_on_file                 0.001283             -0.002387
# cb_person_cred_hist_length                0.014615              0.034690
# loan_intent_DEBTCONSOLIDATION            -0.207635             -0.197351
# loan_intent_EDUCATION                    -0.237233             -0.225483
# loan_intent_HOMEIMPROVEMENT              -0.168912             -0.160546
# loan_intent_MEDICAL                       1.000000             -0.215749
# loan_intent_PERSONAL                     -0.215749              1.000000
# loan_intent_VENTURE                      -0.219344             -0.208480
#
#                                loan_intent_VENTURE
# person_age                               -0.006729
# person_income                             0.006434
# person_home_ownership                     0.082531
# person_emp_length                         0.006238
# loan_grade                               -0.010284
# loan_amnt                                -0.000916
# loan_int_rate                            -0.009010
# loan_status                              -0.079333
# loan_percent_income                       0.001240
# cb_person_default_on_file                -0.003436
# cb_person_cred_hist_length               -0.007332
# loan_intent_DEBTCONSOLIDATION            -0.200639
# loan_intent_EDUCATION                    -0.229239
# loan_intent_HOMEIMPROVEMENT              -0.163220
# loan_intent_MEDICAL                      -0.219344
# loan_intent_PERSONAL                     -0.208480
# loan_intent_VENTURE                       1.000000

# %% [markdown]
# ## Training  Classification Model

# %%
X, y = df.drop('loan_status', axis =1), df.loan_status

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.890497737556561
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      6831
#            1       0.75      0.78      0.76      2009
#
#     accuracy                           0.89      8840
#    macro avg       0.84      0.85      0.85      8840
# weighted avg       0.89      0.89      0.89      8840

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)


y_pred_rf = rf.predict(X_test)


print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9333710407239819
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      6831
#            1       0.97      0.73      0.83      2009
#
#     accuracy                           0.93      8840
#    macro avg       0.95      0.86      0.90      8840
# weighted avg       0.94      0.93      0.93      8840

# %%
from sklearn.linear_model import LogisticRegression


log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

y_pred_log_reg = log_reg.predict(X_test)


print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_log_reg))
print(classification_report(y_test, y_pred_log_reg))
# Out:
# Logistic Regression Accuracy: 0.8012443438914028
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      6831
#            1       0.76      0.19      0.30      2009
#
#     accuracy                           0.80      8840
#    macro avg       0.78      0.58      0.59      8840
# weighted avg       0.79      0.80      0.75      8840

# %%
from sklearn.svm import SVC


svm = SVC()
svm.fit(X_train, y_train)


y_pred_svm = svm.predict(X_test)


print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.8069004524886878
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      6831
#            1       0.81      0.20      0.32      2009
#
#     accuracy                           0.81      8840
#    macro avg       0.81      0.59      0.60      8840
# weighted avg       0.81      0.81      0.76      8840

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=31)
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.8352941176470589
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      6831
#            1       0.74      0.43      0.54      2009
#
#     accuracy                           0.84      8840
#    macro avg       0.79      0.69      0.72      8840
# weighted avg       0.82      0.84      0.82      8840

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM','KNN']
accuracies = [
    accuracy_score(y_test, y_pred_log_reg),
    accuracy_score(y_test, y_pred_dt),
    accuracy_score(y_test, y_pred_rf),
    accuracy_score(y_test, y_pred_svm),
    accuracy_score(y_test, y_pred_knn)
]


for model, accuracy in zip(models, accuracies):
    print(f"{model}: {accuracy:.4f}")
# Out:
# Logistic Regression: 0.8012
# Decision Tree: 0.8905
# Random Forest: 0.9334
# SVM: 0.8069
# KNN: 0.8353

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM','KNN']
accuracies = [
    accuracy_score(y_test, y_pred_log_reg),
    accuracy_score(y_test, y_pred_dt),
    accuracy_score(y_test, y_pred_rf),
    accuracy_score(y_test, y_pred_svm),
    accuracy_score(y_test, y_pred_knn)
]


for model, accuracy in zip(models, accuracies):
    print(f"{model}: {accuracy:.4f}")
# Out:
# Logistic Regression: 0.8012
# Decision Tree: 0.8905
# Random Forest: 0.9334
# SVM: 0.8069
# KNN: 0.8353

# %%
plt.bar(models, accuracies)
plt.xlabel("Models")
plt.ylabel("Accuracy Score")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)


grid_search.fit(X_train, y_train)


print("Best Parameters:", grid_search.best_params_)


best_rf_model = grid_search.best_estimator_


y_pred_best_rf = best_rf_model.predict(X_test)
print("Tuned Random Forest Accuracy:", accuracy_score(y_test, y_pred_best_rf))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 300}
# Tuned Random Forest Accuracy: 0.9331447963800905
